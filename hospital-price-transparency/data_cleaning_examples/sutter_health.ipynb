# %% [markdown]
# ### Sutter Health
#
# We have quite a few of these in our database and I thought it might be instructive to pull some of them.
#
# I'm gonna use the (unauthenticated) DoltHub API to get the files. I already manually checked that the files matched the right hospitals.

# %%
import requests
owner, repo, branch = "dolthub", "standard-charge-files", "main"
query = """SELECT ccn, doing_business_as_name, standard_charge_file_url FROM hospitals where standard_charge_file_indirect_url = 'https://www.sutterhealth.org/for-patients/healthcare-cost-transparency'"""
res = requests.get(
    "https://www.dolthub.com/api/v1alpha1/{}/{}".format(owner, repo, branch),
    params={"q": query},
    # headers={ "authorization": "token dhat.v1.99vtt0kv3dl67u552r4d9i2heib0t7jfiergefsd9dp9bl51tls0" },
)

# %% [markdown]
# Let's put these in a dataframe:

# %%
import polars as pl
files = pl.DataFrame(res.json()['rows'])

# %%
files.head().to_pandas()
# Out:
#       ccn                             doing_business_as_name  \
# 0  050766              SUTTER SURGICAL HOSPITAL-NORTH VALLEY
# 1  050417
# 2  050108                   SUTTER MEDICAL CENTER SACRAMENTO
# 3  050309                    SUTTER ROSEVILLE MEDICAL CENTER
# 4  050047  CALIFORNIA PACIFIC MEDICAL CENTER-VAN NESS CAMPUS
#
#                             standard_charge_file_url
# 0  https://www.sutterhealth.org/pdf/chargemaster/...
# 1  https://www.sutterhealth.org/pdf/chargemaster/...
# 2  https://www.sutterhealth.org/pdf/chargemaster/...
# 3  https://www.sutterhealth.org/pdf/chargemaster/...
# 4  https://www.sutterhealth.org/pdf/chargemaster/...

# %% [markdown]
# Sometimes the last_updated is in the first row of the file.
#
# It's always of the form MM-DD-YYYY. It might even be the same for all the files, but I decided to check it in python.
#
# I just look through the first columns and rows for a date string. If I find one, I save that as "last_updated".

# %%
import re

def find_last_updated(df):
    
    pat = re.compile(r'\b\d{1,2}\/\d{1,2}\/\d{4}\b')
    
    # check the column row first
    for c in df.columns:
        if re.match(pat, c):
            mm, dd, yyyy = c.split('/')
            last_updated = f'{yyyy}-{mm}-{dd}'
            return last_updated
        
    # check the first few row values
    for row in df.rows()[:3]:
        for c in row:
            if not c:
                continue
            if re.match(pat, c):
                mm, dd, yyyy = c.split('/')
                last_updated = f'{yyyy}-{mm}-{dd}'
                return last_updated
            
    return

# %% [markdown]
# Sometimes there's header metadata. This looks for any time a row contains the header
# columns, then renames the columns to match that row. Then we slice off the rows that
# contain the metadata. We limit ourselves to searching the first 10 rows

# %%
def find_header_row(df):

    header_row_cols = ['ID', 'SERVICE_SETTING', 'DESCRIPTION', 'CPT', 'NDC', 'REVENUE_CODE']
    
    # case: header is correct
    if all(c in df.columns for c in header_row_cols):
        return df
    
    # case: header is in a row
    for i in range(10):
        if all(c in df.to_dicts()[i].values() for c in header_row_cols):
            df = df.rename(df.to_dicts()[i])
            df = df[i+1:]
            return df
        else:
            print(df[i])

# %% [markdown]
# Rename the cols to fit the unified schema.

# %%
rename_dict = ({
    'ID':'internal_code',
    'SERVICE_SETTING':'patient_class',
    'DESCRIPTION':'description',
    'CPT':'hcpcs_cpt',
    'NDC':'ndc',
    'REVENUE_CODE':'rev_code',
})

def rename_cols(df):
    df = df.rename(rename_dict)
    return df

# %% [markdown]
# The MSDRG and APR-DRG codes are actually hidden in the "internal_code" column. So we extract them out.

# %%
def extract_noncpt(df):
    
    # APR-DRG part
    df_aprdrg = df.with_columns([
        pl.col('internal_code').str.extract('APRDRG-(\d{3}-\d{1})').alias('code'),
        pl.lit('ms-drg').alias('code_prefix'),
        pl.col('internal_code').alias('code_orig'),
    ]).filter(pl.col('code').is_not_null()).drop('hcpcs_cpt')
    
    # MS-DRG part
    df_msdrg = df.with_columns([
        pl.col('internal_code').str.extract('MSDRG-(\d{3})').alias('code'),
        pl.lit('ms-drg').alias('code_prefix'),
        pl.col('internal_code').alias('code_orig'),
    ]).filter(pl.col('code').is_not_null()).drop('hcpcs_cpt')
    
    # HCPCS part. Note that there's no code_orig, since we don't extract the code
    # from anything
    df_hcpcs = df.with_columns([
        pl.lit('hcpcs_cpt').alias('code_prefix'),
        pl.lit(None).alias('code_orig').cast(str),
    ]).filter(pl.col('hcpcs_cpt').is_not_null()).rename({'hcpcs_cpt':'code'})
    
    # In order to stack the dataframes we need to make sure they all have the 
    # same column order. Pick one column and reorder the others
    col_order = df_aprdrg.columns
    df_msdrg = df_msdrg.select(col_order)
    df_hcpcs = df_hcpcs.select(col_order)
        
    return pl.concat([df_aprdrg, df_msdrg, df_hcpcs])

# %%
def melt_payers(df):
    # Payers go from horizontal to vertical
    id_vars = list(rename_dict.values())
    value_vars = [c for c in df.columns if c not in id_vars]
    variable_name = 'payer_orig'
    value_name = 'rate'
    df = df.melt(
        id_vars, 
        value_vars,
        variable_name,
        value_name
    )
    return df

# %%
def rate_as_float(df):
    # $3,012,212.00 --> 3012212.00
    df = df.with_columns(
        pl.col('rate').str.strip('$').str.strip(' ').str.replace_all(',', '').cast(float)
    )
    return df

# %%
def get_payer_cat(df):
    df = df.with_columns(
        pl.when(pl.col('payer_orig').str.to_lowercase().str.contains('gross ')).then('gross')
        .when(pl.col('payer_orig').str.to_lowercase().str.contains('cash ')).then('cash')
        .when(pl.col('payer_orig').str.to_lowercase().str.contains('minimum ')).then('min')
        .when(pl.col('payer_orig').str.to_lowercase().str.contains('maximum ')).then('max')
        .otherwise('payer').alias('payer_category')
    )
    return df

# %%
def extract_ein(url):
    ein = url.split('/')[-1].split('-')[0]
    ein_dashed = ein[:2] + '-' + ein[2:]
    return ein_dashed

# %%
def extract_filename(url):
    return url.split('/')[-1]

# %%
def extract_payerplan_details(df):
    df = df.with_columns([
        (
            pl.when(pl.col('payer_orig').str.contains('Cigna')).then('Cigna')
            .when(pl.col('payer_orig').str.contains('Blue Shield')).then('Blue Shield')
            .when(pl.col('payer_orig').str.contains('Aetna')).then('Aetna')
            .when(pl.col('payer_orig').str.contains('Health Net')).then('Health Net')
            .when(pl.col('payer_orig').str.contains('Humana')).then('Humana')
            .when(pl.col('payer_orig').str.contains('Sutter Health Plus')).then('Sutter Health Plus')
            .when(pl.col('payer_orig').str.contains('United')).then('United')
            .when(pl.col('payer_orig').str.contains('Alignment')).then('Alignment')
            .when(pl.col('payer_orig').str.contains('Multiplan')).then('Multiplan')
            .otherwise(None)
        ).alias('payer_name'),
        (
            pl.when(pl.col('payer_orig').str.contains('HMO/PPO')).then('hmo ppo')
            .when(pl.col('payer_orig').str.contains('HMO / PPO')).then('hmo ppo')
            .when(pl.col('payer_orig').str.contains('Medicare Adv_ HMO')).then('medicare_advantage hmo')
            .when(pl.col('payer_orig').str.contains('HMO / POS')).then('hmo pos')
            .when(pl.col('payer_orig').str.contains('HMO and PPO')).then('hmo ppo')
            .when(pl.col('payer_orig').str.contains(' EPO')).then('epo')
            .when(pl.col('payer_orig').str.contains(' PPO')).then('ppo')
            .when(pl.col('payer_orig').str.contains('Commercial Out of Network - Emergency')).then('oon emergency')
            .when(pl.col('payer_orig').str.contains('Commercial Out of Network')).then('oon')
            .when(pl.col('payer_orig').str.contains('Commercial')).then('commerical')
            .when(pl.col('payer_orig').str.contains('Individual')).then('individual')
            .when(pl.col('payer_orig').str.contains('Medi-Cal')).then('medi-cal')
            .otherwise(None)
        ).alias('plan_name'),
    ])
    
    return df

# %%
from tqdm import tqdm

dfs = []

for row in tqdm(files.rows()):
    
    ccn, dba, url = row
    
    # this one's busted
    if ccn == '124001':
        continue
    
    df = pl.read_csv(url, encoding = 'latin-1', null_values = ['NULL'])
    
    last_updated = df.pipe(find_last_updated)
    
    df = (df
          .pipe(find_header_row)
          .pipe(rename_cols)
          .pipe(melt_payers)
          .filter(pl.col('rate').is_not_null())
          .pipe(rate_as_float)
          .pipe(get_payer_cat)
          .pipe(extract_noncpt)
          .pipe(extract_payerplan_details)
         )
    
    df = df.with_columns([
        pl.col('patient_class').str.to_lowercase(),
        pl.col('rev_code').cast(str).str.zfill(4),
        pl.lit(ccn).alias('hospital_ccn'),
        pl.lit(url).alias('url'),
        pl.lit(extract_ein(url)).alias('hospital_ein'),
        pl.lit(extract_filename(url)).alias('filename'),
        pl.lit(last_updated).alias('file_last_updated').cast(str)
    ])
    
    df = df.unique()
    
    dfs.append(df)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [01:30<00:00,  3.77s/it]

# %%
pl.concat(dfs).write_csv('sutter.csv')

# %%
col_order = [
    'hospital_ccn',
    'hospital_ein',
    'description',
    'internal_code',
    'code_orig',
    'code_prefix',
    'code',
    'ndc',
    'rev_code',
    'patient_class',
    'payer_category',
    'payer_orig',
    'payer_name',
    'plan_name',
    'rate',
    'filename',
    'file_last_updated',
    'url',
]

# %%
pl.concat(dfs).sample(20).select(col_order).to_pandas()
# Out:
#    hospital_ccn hospital_ein  \
# 0        050043   94-0562680
# 1        050488   94-0562680
# 2        050557   94-1156621
# 3        050309   94-1156621
# 4        050055   94-0562680
# 5        050305   94-0562680
# 6        050309   94-1156621
# 7        050557   94-1156621
# 8        050055   94-0562680
# 9        050557   94-1156621
# 10       050047   94-0562680
# 11       050008   94-0562680
# 12       050043   94-0562680
# 13       050047   94-0562680
# 14       050047   94-0562680
# 15       050047   94-0562680
# 16       050309   94-1156621
# 17       050055   94-0562680
# 18       050108   94-1156621
# 19       050498   94-1156621
#
#                                           description  \
# 0                         STENT ELUVIA  6X100MMX130CM
# 1                                 KIT PEG PONSKY 20FR
# 2                         CONE CNTRL FEM PSN TM SZ LG
# 3   All Services for Outpatient Surgery for Remove...
# 4                      NAIL TI CANLT STRL 11MMX130DEG
# 5              HCHG TH LACTATION CLINIC VISIT LEVEL 1
# 6                      SCREW TFN ADV SYS FENSTD 105MM
# 7                  HCHG TAP BLOCK BIL BY INJECTION(S)
# 8                              SCREW 4.0X26MM IM NAIL
# 9                     HCHG PERC D-E COR STENT ATHER S
# 10                  ALBUTEROL 1.25 MG/3ML 0.042% NEBU
# 11                                  OCCLUDER RUMI SYS
# 12                      EXTRACTOR STONE NITINOL 2.4FR
# 13  HCHG APC OBS OR INPT CARE SVCS INCL ADM/DSCHRG...
# 14            HCHG US SONOHYSTEROGRAM SALINE INFUSION
# 15                            OXALIPLATIN 5MG/ML SOLN
# 16                             IMP GEL MODERATE 210CC
# 17                            SCREW CORTEX 3.5MMX44MM
# 18                                   CATH GUIDE 7 JL4
# 19                         ACETAMINOPHEN 10MG/ML SOLN
#
#                  internal_code code_orig code_prefix   code           ndc  \
# 0       OP_SUP-60050105-540354      None   hcpcs_cpt  C1874          None
# 1       IP_SUP-60050153-103713      None   hcpcs_cpt  Z7610          None
# 2       OP_SUP-60050088-574922      None   hcpcs_cpt  C1776          None
# 3                OP_CASE-24120      None   hcpcs_cpt  24120          None
# 4       OP_SUP-60050073-478173      None   hcpcs_cpt  C1713          None
# 5                  OP-87200614      None   hcpcs_cpt  G0463          None
# 6       OP_SUP-60050073-541900      None   hcpcs_cpt  C1713          None
# 7                  IP-21000788      None   hcpcs_cpt  64488          None
# 8       OP_SUP-60050073-278339      None   hcpcs_cpt  C1713          None
# 9                  OP-30900195      None   hcpcs_cpt  C9602          None
# 10     OP_RX-81000008-ERX47328      None   hcpcs_cpt  J7613          None
# 11      OP_SUP-60050050-122700      None   hcpcs_cpt  C2628          None
# 12      OP_SUP-60050153-367422      None   hcpcs_cpt  Z7610          None
# 13                 OP-88000016      None   hcpcs_cpt  99234          None
# 14                 OP-30100040      None   hcpcs_cpt  76831          None
# 15    OP_RX-81000008-ERX122711      None   hcpcs_cpt  J9263  61703-363-22
# 16      IP_SUP-60050094-563237      None   hcpcs_cpt  C1789          None
# 17      IP_SUP-60050073-203166      None   hcpcs_cpt  C1713          None
# 18      OP_SUP-60050042-489591      None   hcpcs_cpt  C1887          None
# 19  OP_RX-81000008-ERX50004047      None   hcpcs_cpt  J0131  43825-102-01
#
#    rev_code patient_class payer_category  \
# 0      0278    outpatient          payer
# 1      0272     inpatient          payer
# 2      0278    outpatient          payer
# 3      None    outpatient          payer
# 4      0278    outpatient          payer
# 5      0510    outpatient          payer
# 6      0278    outpatient          payer
# 7      0361     inpatient          payer
# 8      0278    outpatient            min
# 9      0481    outpatient          payer
# 10     0250    outpatient          payer
# 11     0272    outpatient          payer
# 12     0272    outpatient          payer
# 13     0987    outpatient          payer
# 14     0402    outpatient          payer
# 15     0636    outpatient          payer
# 16     0278     inpatient          payer
# 17     0278     inpatient            min
# 18     0272    outpatient          payer
# 19     0250    outpatient          payer
#
#                                            payer_orig   payer_name  \
# 0                                       Multiplan PPO    Multiplan
# 1                                     HealthSmart PPO         None
# 2                     Aetna Commercial Out of Network        Aetna
# 3                    United Medicare Adv_ HMO and PPO       United
# 4         Anthem Blue Cross Commercial Out of Network         None
# 5                         Sutter | Aetna Self Insured        Aetna
# 6   Cigna Commercial Out of Network - Emergency Se...        Cigna
# 7                                       Multiplan PPO    Multiplan
# 8                            Minimum Negotiated Price         None
# 9   Aetna Commercial Out of Network - Emergency Se...        Aetna
# 10                    United Signature Value Alliance       United
# 11  Blue Shield Commercial Out of Network - Emerge...  Blue Shield
# 12  Cigna Commercial Out of Network - Emergency Se...        Cigna
# 13        Anthem Blue Cross Commercial Out of Network         None
# 14                  Alignment Medicare Adv_ HMO / PPO    Alignment
# 15  Cigna Commercial Out of Network - Emergency Se...        Cigna
# 16  United Commercial Out of Network - Emergency S...       United
# 17                           Minimum Negotiated Price         None
# 18               Health Net Commercial Out of Network   Health Net
# 19                                   United HMO / POS       United
#
#                  plan_name      rate  \
# 0                      ppo  11418.00
# 1                      ppo   1194.72
# 2                      oon  18552.51
# 3   medicare_advantage hmo   3998.92
# 4                      oon   6875.85
# 5                     None     76.80
# 6            oon emergency   2793.01
# 7                      ppo    794.82
# 8                     None    670.19
# 9            oon emergency  28210.44
# 10                    None      0.00
# 11           oon emergency    686.74
# 12           oon emergency   1179.52
# 13                     oon    369.00
# 14                 hmo ppo    347.24
# 15           oon emergency      0.44
# 16           oon emergency   4389.00
# 17                    None    152.68
# 18                     oon    309.96
# 19                 hmo pos      2.00
#
#                                              filename file_last_updated  \
# 0   940562680-1295181477_ALTA-BATES-SUMMIT-MEDICAL...              None
# 1   940562680-1063812907_EDEN-MEDICAL-CENTER_stand...        2022-12-15
# 2   941156621-1699129601_MEMORIAL-MEDICAL-CENTER_s...        2022-12-15
# 3   941156621-1356390264_SUTTER-ROSEVILLE-MEDICAL-...        2022-12-15
# 4   940562680-1730238007_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 5   940562680-1639523004_ALTA-BATES-SUMMIT-MEDICAL...              None
# 6   941156621-1356390264_SUTTER-ROSEVILLE-MEDICAL-...        2022-12-15
# 7   941156621-1699129601_MEMORIAL-MEDICAL-CENTER_s...        2022-12-15
# 8   940562680-1730238007_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 9   941156621-1699129601_MEMORIAL-MEDICAL-CENTER_s...        2022-12-15
# 10  940562680-1740348929_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 11  940562680-1659439834_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 12  940562680-1295181477_ALTA-BATES-SUMMIT-MEDICAL...              None
# 13  940562680-1740348929_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 14  940562680-1740348929_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 15  940562680-1740348929_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 16  941156621-1356390264_SUTTER-ROSEVILLE-MEDICAL-...        2022-12-15
# 17  940562680-1730238007_CALIFORNIA-PACIFIC-MEDICA...        2022-12-15
# 18  941156621-1811946734_SUTTER-MEDICAL-CENTER-SAC...        2022-12-15
# 19  941156621-1194774299_SUTTER-AUBURN-FAITH-HOSPI...        2022-12-15
#
#                                                   url
# 0   https://www.sutterhealth.org/pdf/chargemaster/...
# 1   https://www.sutterhealth.org/pdf/chargemaster/...
# 2   https://www.sutterhealth.org/pdf/chargemaster/...
# 3   https://www.sutterhealth.org/pdf/chargemaster/...
# 4   https://www.sutterhealth.org/pdf/chargemaster/...
# 5   https://www.sutterhealth.org/pdf/chargemaster/...
# 6   https://www.sutterhealth.org/pdf/chargemaster/...
# 7   https://www.sutterhealth.org/pdf/chargemaster/...
# 8   https://www.sutterhealth.org/pdf/chargemaster/...
# 9   https://www.sutterhealth.org/pdf/chargemaster/...
# 10  https://www.sutterhealth.org/pdf/chargemaster/...
# 11  https://www.sutterhealth.org/pdf/chargemaster/...
# 12  https://www.sutterhealth.org/pdf/chargemaster/...
# 13  https://www.sutterhealth.org/pdf/chargemaster/...
# 14  https://www.sutterhealth.org/pdf/chargemaster/...
# 15  https://www.sutterhealth.org/pdf/chargemaster/...
# 16  https://www.sutterhealth.org/pdf/chargemaster/...
# 17  https://www.sutterhealth.org/pdf/chargemaster/...
# 18  https://www.sutterhealth.org/pdf/chargemaster/...
# 19  https://www.sutterhealth.org/pdf/chargemaster/...
