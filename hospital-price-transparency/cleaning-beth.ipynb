# %%
import polars as pl

# %%
df = pl.read_csv('170040_sample.csv', skip_rows = 1, null_values = ["N/A"])

# %%
ip_cols = [c for c in df.columns if c.startswith('IP')]
op_cols = [c for c in df.columns if c.startswith('OP')]

# %%
ip_cols
# Out:
# ['IPPricingDetail',
#  'IPPrice',
#  'IPDiscountedCashPrice',
#  'IPExpectedReimbursement',
#  'IPNegotiatedMaximumPrice',
#  'IPNegotiatedMinimumPrice']

# %%
op_cols
# Out:
# ['OPPrice',
#  'OPDiscountedCashPrice',
#  'OPExpectedReimbursement',
#  'OPNegotiatedMaximumPrice',
#  'OPNegotiatedMinimumPrice']

# %% [markdown]
# Here's something we can do right away:

# %%
df.sample(5)
# Out:
# shape: (5, 21)
# ┌───────────┬──────────┬────────┬──────────┬─────┬────────────┬────────────┬────────────┬──────────┐
# │ Procedure ┆ CodeType ┆ Code   ┆ RevCode  ┆ ... ┆ OPExpected ┆ OPNegotiat ┆ OPNegotiat ┆ BillType │
# │ ---       ┆ ---      ┆ ---    ┆ ---      ┆     ┆ Reimbursem ┆ edMaximumP ┆ edMinimumP ┆ ---      │
# │ str       ┆ str      ┆ str    ┆ str      ┆     ┆ ent        ┆ rice       ┆ rice       ┆ str      │
# │           ┆          ┆        ┆          ┆     ┆ ---        ┆ ---        ┆ ---        ┆          │
# │           ┆          ┆        ┆          ┆     ┆ str        ┆ f64        ┆ f64        ┆          │
# ╞═══════════╪══════════╪════════╪══════════╪═════╪════════════╪════════════╪════════════╪══════════╡
# │ 10061     ┆ CPT      ┆ 10061  ┆ 0450 -   ┆ ... ┆ 27,959.07  ┆ 31453.98   ┆ 132.01     ┆ HB       │
# │           ┆          ┆        ┆ EMERGENC ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ Y ROOM - ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ GENERAL  ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ...      ┆     ┆            ┆            ┆            ┆          │
# │ 11421     ┆ CPT      ┆ 11421  ┆ 0761 -   ┆ ... ┆ null       ┆ null       ┆ null       ┆ HB       │
# │           ┆          ┆        ┆ TREATMEN ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ T/OBSERV ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ATION    ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ROO...   ┆     ┆            ┆            ┆            ┆          │
# │ 11406     ┆ CPT      ┆ 11406  ┆ 0761 -   ┆ ... ┆ 7,527.50   ┆ 33283.52   ┆ 482.72     ┆ HB       │
# │           ┆          ┆        ┆ TREATMEN ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ T/OBSERV ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ATION    ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ROO...   ┆     ┆            ┆            ┆            ┆          │
# │ 11402     ┆ CPT      ┆ 11402  ┆ 0761 -   ┆ ... ┆ null       ┆ null       ┆ null       ┆ HB       │
# │           ┆          ┆        ┆ TREATMEN ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ T/OBSERV ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ATION    ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ROO...   ┆     ┆            ┆            ┆            ┆          │
# │ HCORR3272 ┆ EAP      ┆  C1750 ┆ 0270 -   ┆ ... ┆ 14,962.50  ┆ 19237.5    ┆ 650.0      ┆ HB       │
# │ 0001      ┆          ┆        ┆ MEDICAL/ ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ SURGICAL ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ SUPPLIES ┆     ┆            ┆            ┆            ┆          │
# │           ┆          ┆        ┆ ...      ┆     ┆            ┆            ┆            ┆          │
# └───────────┴──────────┴────────┴──────────┴─────┴────────────┴────────────┴────────────┴──────────┘

# %%
df = df.with_columns([
    pl.when(pl.col('BillType') == 'HB').then('facility').otherwise(
        pl.when(pl.col('BillType') == 'PB').then('professional')).alias('blling_class')
])

# %%
df.sample(5)
# Out:
# shape: (5, 22)
# ┌───────────┬──────────┬───────┬───────────┬─────┬────────────┬────────────┬──────────┬────────────┐
# │ Procedure ┆ CodeType ┆ Code  ┆ RevCode   ┆ ... ┆ OPNegotiat ┆ OPNegotiat ┆ BillType ┆ blling_cla │
# │ ---       ┆ ---      ┆ ---   ┆ ---       ┆     ┆ edMaximumP ┆ edMinimumP ┆ ---      ┆ ss         │
# │ str       ┆ str      ┆ str   ┆ str       ┆     ┆ rice       ┆ rice       ┆ str      ┆ ---        │
# │           ┆          ┆       ┆           ┆     ┆ ---        ┆ ---        ┆          ┆ str        │
# │           ┆          ┆       ┆           ┆     ┆ f64        ┆ f64        ┆          ┆            │
# ╞═══════════╪══════════╪═══════╪═══════════╪═════╪════════════╪════════════╪══════════╪════════════╡
# │ 10180     ┆ CPT      ┆ 10180 ┆ 0761 -    ┆ ... ┆ 18361.42   ┆ 2330.89    ┆ HB       ┆ facility   │
# │           ┆          ┆       ┆ TREATMENT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ /OBSERVAT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ION       ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ROO...    ┆     ┆            ┆            ┆          ┆            │
# │ 11401     ┆ CPT      ┆ 11401 ┆ 0761 -    ┆ ... ┆ null       ┆ null       ┆ HB       ┆ facility   │
# │           ┆          ┆       ┆ TREATMENT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ /OBSERVAT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ION       ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ROO...    ┆     ┆            ┆            ┆          ┆            │
# │ 11406     ┆ CPT      ┆ 11406 ┆ 0761 -    ┆ ... ┆ 33283.52   ┆ 482.72     ┆ HB       ┆ facility   │
# │           ┆          ┆       ┆ TREATMENT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ /OBSERVAT ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ION       ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ROO...    ┆     ┆            ┆            ┆          ┆            │
# │ 10007     ┆ CPT      ┆ 10007 ┆ null      ┆ ... ┆ null       ┆ null       ┆ HB       ┆ facility   │
# │ 10160     ┆ CPT      ┆ 10160 ┆ 0361 -    ┆ ... ┆ 3972.6     ┆ 158.33     ┆ HB       ┆ facility   │
# │           ┆          ┆       ┆ OPERATING ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ ROOM      ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ SERVICES  ┆     ┆            ┆            ┆          ┆            │
# │           ┆          ┆       ┆ -...      ┆     ┆            ┆            ┆          ┆            │
# └───────────┴──────────┴───────┴───────────┴─────┴────────────┴────────────┴──────────┴────────────┘

# %% [markdown]
# We can also extract the revenue code easily:

# %%
df = df.with_columns([
    pl.col('RevCode').str.extract('(\d{4})\s-').alias('rev_code')
])

# %% [markdown]
# Let's work with just the IP cols.

# %%
df_ip = df.select([c for c in df.columns if c not in op_cols])

# %%
df_ip = df_ip.with_columns([
    pl.lit('inpatient').alias('patient_class')
])

# %%
df_ip.head()
# Out:
# shape: (5, 19)
# ┌────────────┬──────────┬────────┬───────────┬─────┬──────────┬────────────┬──────────┬────────────┐
# │ Procedure  ┆ CodeType ┆ Code   ┆ RevCode   ┆ ... ┆ BillType ┆ blling_cla ┆ rev_code ┆ patient_cl │
# │ ---        ┆ ---      ┆ ---    ┆ ---       ┆     ┆ ---      ┆ ss         ┆ ---      ┆ ass        │
# │ str        ┆ str      ┆ str    ┆ str       ┆     ┆ str      ┆ ---        ┆ str      ┆ ---        │
# │            ┆          ┆        ┆           ┆     ┆          ┆ str        ┆          ┆ str        │
# ╞════════════╪══════════╪════════╪═══════════╪═════╪══════════╪════════════╪══════════╪════════════╡
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# └────────────┴──────────┴────────┴───────────┴─────┴──────────┴────────────┴──────────┴────────────┘

# %% [markdown]
# Now we need to split up the cash, gross, and min/max rates from the payer rates.

# %%
df_ip.columns
# Out:
# ['Procedure',
#  'CodeType',
#  'Code',
#  'RevCode',
#  'NDC',
#  'ProcedureDescription',
#  'Payer',
#  'Plan(s)',
#  'IPPricingDetail',
#  'Quantity',
#  'IPPrice',
#  'IPDiscountedCashPrice',
#  'IPExpectedReimbursement',
#  'IPNegotiatedMaximumPrice',
#  'IPNegotiatedMinimumPrice',
#  'BillType',
#  'blling_class',
#  'rev_code',
#  'patient_class']

# %%
df_ip_payer = df_ip.select([
    'Procedure',
    'CodeType',
    'Code',
    'RevCode',
    'NDC',
    'ProcedureDescription',
    'IPPricingDetail',
    'Payer',
    'Plan(s)',
    'Quantity',
    'IPExpectedReimbursement',
    'BillType',
    'blling_class',
    'rev_code',
    'patient_class'
])

# %%
df_ip_payer.rename({
    'IPExpectedReimbursement':'rate'
}).filter(pl.col('rate').is_not_null())
# Out:
# shape: (0, 15)
# ┌───────────┬──────────┬──────┬─────────┬─────┬──────────┬──────────────┬──────────┬───────────────┐
# │ Procedure ┆ CodeType ┆ Code ┆ RevCode ┆ ... ┆ BillType ┆ blling_class ┆ rev_code ┆ patient_class │
# │ ---       ┆ ---      ┆ ---  ┆ ---     ┆     ┆ ---      ┆ ---          ┆ ---      ┆ ---           │
# │ str       ┆ str      ┆ str  ┆ str     ┆     ┆ str      ┆ str          ┆ str      ┆ str           │
# ╞═══════════╪══════════╪══════╪═════════╪═════╪══════════╪══════════════╪══════════╪═══════════════╡
# └───────────┴──────────┴──────┴─────────┴─────┴──────────┴──────────────┴──────────┴───────────────┘

# %%
df_ip_other = df_ip.select([
    'Procedure',
    'CodeType',
    'Code',
    'RevCode',
    'NDC',
    'ProcedureDescription',
    # 'Payer',
    # 'Plan(s)',
    'IPPricingDetail',
    'Quantity',
    'IPPrice',
    'IPDiscountedCashPrice',
    # 'IPExpectedReimbursement',
    'IPNegotiatedMaximumPrice',
    'IPNegotiatedMinimumPrice',
    'BillType',
    'blling_class',
    'rev_code',
    'patient_class'
])

# %%
df_ip_other.head()
# Out:
# shape: (5, 16)
# ┌────────────┬──────────┬────────┬───────────┬─────┬──────────┬────────────┬──────────┬────────────┐
# │ Procedure  ┆ CodeType ┆ Code   ┆ RevCode   ┆ ... ┆ BillType ┆ blling_cla ┆ rev_code ┆ patient_cl │
# │ ---        ┆ ---      ┆ ---    ┆ ---       ┆     ┆ ---      ┆ ss         ┆ ---      ┆ ass        │
# │ str        ┆ str      ┆ str    ┆ str       ┆     ┆ str      ┆ ---        ┆ str      ┆ ---        │
# │            ┆          ┆        ┆           ┆     ┆          ┆ str        ┆          ┆ str        │
# ╞════════════╪══════════╪════════╪═══════════╪═════╪══════════╪════════════╪══════════╪════════════╡
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 -    ┆ ... ┆ HB       ┆ facility   ┆ 0270     ┆ inpatient  │
# │ 001        ┆          ┆        ┆ MEDICAL/S ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ URGICAL   ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ SUPPLIES. ┆     ┆          ┆            ┆          ┆            │
# │            ┆          ┆        ┆ ..        ┆     ┆          ┆            ┆          ┆            │
# └────────────┴──────────┴────────┴───────────┴─────┴──────────┴────────────┴──────────┴────────────┘

# %%
value_vars = ['IPPrice', 'IPDiscountedCashPrice', 'IPNegotiatedMaximumPrice', 'IPNegotiatedMinimumPrice']
df_ip_other = df_ip_other.melt(
    id_vars = [c for c in df_ip_other.columns if c not in value_vars],
    value_vars = value_vars,
    variable_name = 'payer_name',
    value_name = 'rate'
)

# %%
df_ip_other.head()
# Out:
# shape: (5, 14)
# ┌────────────┬──────────┬────────┬────────────┬─────┬──────────┬────────────┬────────────┬─────────┐
# │ Procedure  ┆ CodeType ┆ Code   ┆ RevCode    ┆ ... ┆ rev_code ┆ patient_cl ┆ payer_name ┆ rate    │
# │ ---        ┆ ---      ┆ ---    ┆ ---        ┆     ┆ ---      ┆ ass        ┆ ---        ┆ ---     │
# │ str        ┆ str      ┆ str    ┆ str        ┆     ┆ str      ┆ ---        ┆ str        ┆ str     │
# │            ┆          ┆        ┆            ┆     ┆          ┆ str        ┆            ┆         │
# ╞════════════╪══════════╪════════╪════════════╪═════╪══════════╪════════════╪════════════╪═════════╡
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ 0270     ┆ inpatient  ┆ IPPrice    ┆ 21375.0 │
# │ 001        ┆          ┆        ┆ ICAL/SURGI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ CAL SUPPLI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ ES...      ┆     ┆          ┆            ┆            ┆         │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ 0270     ┆ inpatient  ┆ IPPrice    ┆ 21375.0 │
# │ 001        ┆          ┆        ┆ ICAL/SURGI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ CAL SUPPLI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ ES...      ┆     ┆          ┆            ┆            ┆         │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ 0270     ┆ inpatient  ┆ IPPrice    ┆ 21375.0 │
# │ 001        ┆          ┆        ┆ ICAL/SURGI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ CAL SUPPLI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ ES...      ┆     ┆          ┆            ┆            ┆         │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ 0270     ┆ inpatient  ┆ IPPrice    ┆ 21375.0 │
# │ 001        ┆          ┆        ┆ ICAL/SURGI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ CAL SUPPLI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ ES...      ┆     ┆          ┆            ┆            ┆         │
# │ HCORR32720 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ 0270     ┆ inpatient  ┆ IPPrice    ┆ 21375.0 │
# │ 001        ┆          ┆        ┆ ICAL/SURGI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ CAL SUPPLI ┆     ┆          ┆            ┆            ┆         │
# │            ┆          ┆        ┆ ES...      ┆     ┆          ┆            ┆            ┆         │
# └────────────┴──────────┴────────┴────────────┴─────┴──────────┴────────────┴────────────┴─────────┘

# %%
df_ip_other = df_ip_other.with_columns([
    pl.when(pl.col('payer_name') == "IPPrice").then('gross').otherwise(
        pl.when(pl.col('payer_name') == "IPDiscountedCashPrice").then('cash').otherwise(
            pl.when(pl.col('payer_name') == "IPNegotiatedMaximumPrice").then('max').otherwise(
                pl.when(pl.col('payer_name') == "IPNegotiatedMinimumPrice").then('min')))).alias('payer_category')
])

# %%
df_ip_other.sample(5)
# Out:
# shape: (5, 15)
# ┌─────────────┬──────────┬────────┬────────────┬─────┬────────────┬────────────┬──────┬────────────┐
# │ Procedure   ┆ CodeType ┆ Code   ┆ RevCode    ┆ ... ┆ patient_cl ┆ payer_name ┆ rate ┆ payer_cate │
# │ ---         ┆ ---      ┆ ---    ┆ ---        ┆     ┆ ass        ┆ ---        ┆ ---  ┆ gory       │
# │ str         ┆ str      ┆ str    ┆ str        ┆     ┆ ---        ┆ str        ┆ str  ┆ ---        │
# │             ┆          ┆        ┆            ┆     ┆ str        ┆            ┆      ┆ str        │
# ╞═════════════╪══════════╪════════╪════════════╪═════╪════════════╪════════════╪══════╪════════════╡
# │ 11012       ┆ CPT      ┆ 11012  ┆ null       ┆ ... ┆ inpatient  ┆ IPPrice    ┆ 0.0  ┆ gross      │
# │ 0398T       ┆ CPT      ┆ 0398T  ┆ null       ┆ ... ┆ inpatient  ┆ IPDiscount ┆ 0.0  ┆ cash       │
# │             ┆          ┆        ┆            ┆     ┆            ┆ edCashPric ┆      ┆            │
# │             ┆          ┆        ┆            ┆     ┆            ┆ e          ┆      ┆            │
# │ 11401       ┆ CPT      ┆ 11401  ┆ 0761 - TRE ┆ ... ┆ inpatient  ┆ IPDiscount ┆ 0.0  ┆ cash       │
# │             ┆          ┆        ┆ ATMENT/OBS ┆     ┆            ┆ edCashPric ┆      ┆            │
# │             ┆          ┆        ┆ ERVATION   ┆     ┆            ┆ e          ┆      ┆            │
# │             ┆          ┆        ┆ ROO...     ┆     ┆            ┆            ┆      ┆            │
# │ HCORR327200 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ inpatient  ┆ IPNegotiat ┆ null ┆ max        │
# │ 01          ┆          ┆        ┆ ICAL/SURGI ┆     ┆            ┆ edMaximumP ┆      ┆            │
# │             ┆          ┆        ┆ CAL SUPPLI ┆     ┆            ┆ rice       ┆      ┆            │
# │             ┆          ┆        ┆ ES...      ┆     ┆            ┆            ┆      ┆            │
# │ HCORR327200 ┆ EAP      ┆  C1750 ┆ 0270 - MED ┆ ... ┆ inpatient  ┆ IPNegotiat ┆ null ┆ min        │
# │ 01          ┆          ┆        ┆ ICAL/SURGI ┆     ┆            ┆ edMinimumP ┆      ┆            │
# │             ┆          ┆        ┆ CAL SUPPLI ┆     ┆            ┆ rice       ┆      ┆            │
# │             ┆          ┆        ┆ ES...      ┆     ┆            ┆            ┆      ┆            │
# └─────────────┴──────────┴────────┴────────────┴─────┴────────────┴────────────┴──────┴────────────┘

# %%
df_ip_other = df_ip_other.filter(pl.col('rate').is_not_null())

# %%
df_ip_other.sample(5)
# Out:
# shape: (5, 15)
# ┌───────────┬──────────┬───────┬──────────────┬─────┬────────────┬─────────────┬──────┬────────────┐
# │ Procedure ┆ CodeType ┆ Code  ┆ RevCode      ┆ ... ┆ patient_cl ┆ payer_name  ┆ rate ┆ payer_cate │
# │ ---       ┆ ---      ┆ ---   ┆ ---          ┆     ┆ ass        ┆ ---         ┆ ---  ┆ gory       │
# │ str       ┆ str      ┆ str   ┆ str          ┆     ┆ ---        ┆ str         ┆ str  ┆ ---        │
# │           ┆          ┆       ┆              ┆     ┆ str        ┆             ┆      ┆ str        │
# ╞═══════════╪══════════╪═══════╪══════════════╪═════╪════════════╪═════════════╪══════╪════════════╡
# │ 11406     ┆ CPT      ┆ 11406 ┆ 0761 - TREAT ┆ ... ┆ inpatient  ┆ IPPrice     ┆ 0.0  ┆ gross      │
# │           ┆          ┆       ┆ MENT/OBSERVA ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ TION ROO...  ┆     ┆            ┆             ┆      ┆            │
# │ 11012     ┆ CPT      ┆ 11012 ┆ null         ┆ ... ┆ inpatient  ┆ IPDiscounte ┆ 0.0  ┆ cash       │
# │           ┆          ┆       ┆              ┆     ┆            ┆ dCashPrice  ┆      ┆            │
# │ 11403     ┆ CPT      ┆ 11403 ┆ 0761 - TREAT ┆ ... ┆ inpatient  ┆ IPPrice     ┆ 0.0  ┆ gross      │
# │           ┆          ┆       ┆ MENT/OBSERVA ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ TION ROO...  ┆     ┆            ┆             ┆      ┆            │
# │ 11043     ┆ CPT      ┆ 11043 ┆ 0361 -       ┆ ... ┆ inpatient  ┆ IPDiscounte ┆ 0.0  ┆ cash       │
# │           ┆          ┆       ┆ OPERATING    ┆     ┆            ┆ dCashPrice  ┆      ┆            │
# │           ┆          ┆       ┆ ROOM         ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ SERVICES     ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ -...         ┆     ┆            ┆             ┆      ┆            │
# │ 10160     ┆ CPT      ┆ 10160 ┆ 0361 -       ┆ ... ┆ inpatient  ┆ IPDiscounte ┆ 0.0  ┆ cash       │
# │           ┆          ┆       ┆ OPERATING    ┆     ┆            ┆ dCashPrice  ┆      ┆            │
# │           ┆          ┆       ┆ ROOM         ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ SERVICES     ┆     ┆            ┆             ┆      ┆            │
# │           ┆          ┆       ┆ -...         ┆     ┆            ┆             ┆      ┆            │
# └───────────┴──────────┴───────┴──────────────┴─────┴────────────┴─────────────┴──────┴────────────┘
